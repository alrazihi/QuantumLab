# %% [markdown]
# # Grover's Algorithm
# This notebook discusses Grover's algorithm for searching unsorted databases.

# %%
# Import Required Libraries
from qiskit import QuantumCircuit, Aer, execute
